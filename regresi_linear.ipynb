# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
jumlah_data = 150

x=np.array([i*0.2+np.random.randn() for i in range(jumlah_data)])
y=np.array([i*0.2 for i in range(jumlah_data)])

# %% [markdown]
# Generate Data

# %%
plt.scatter(x,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Fungsi Linear

# %%
def linear_regression(x,gradien):
    y = gradien*x
    return y

# %%
x_prediksi = np.array([0,10])
m_init = 5
y_prediksi = linear_regression(x_prediksi,m_init)

# %%
# plt.scatter(x,y)
# plt.plot(x_prediksi,y_prediksi)
# plt.axis([0,10,0,10])
# plt.show()

# %% [markdown]
# ### menghitung prediksi

# %%
m_prediksi = m_init
m_list_prediksi =[]
y_list_prediksi =[]
x_list_prediksi =[]

learning_rate = 0.1

for i in range(1,jumlah_data):
    y_prediksi = linear_regression(x[i],m_prediksi)
    y_actual = y[i]

    error = y_actual-y_prediksi

    delta_m =learning_rate*error/x[i]

    m_prediksi =m_prediksi+delta_m

    m_list_prediksi.append(m_prediksi)
    y_list_prediksi.append(linear_regression(np.array([0,10]),m_prediksi)) #prediksi y
    x_list_prediksi.append(np.array([0,10])) #actual y

# %% [markdown]
# ### Visualisasi

# %%
fig = plt.figure(figsize=(4,4))
line, = plt.plot([],[],"Blue")

def animate(frame_number):
    x= x_list_prediksi[frame_number]
    y= y_list_prediksi[frame_number]
    line.set_data((x,y))
    return line 

plt.scatter(x,y)
plt.axis([0,10,0,10])
anime = FuncAnimation(fig,animate,frames=100,interval=100,repeat=False)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
